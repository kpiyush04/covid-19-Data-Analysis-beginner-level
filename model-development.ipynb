# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-30-2020_1100.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-27-2020_0900.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-11-2020_2044.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-12-2020_1020.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-06-2020_1318.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-21-2020_2200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-06-2020_2005.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-27-2020_1900.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-02-2020_0500.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-24-2020_0000.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-03-2020_1230.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-23-2020_1200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-26-2020_1100.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-31-2020_1400.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-03-2020_2140.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-08-2020_2304.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-28-2020_2300.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/.gitignore
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-22-2020_1200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-27-2020_2030.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-08-2020_1024.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/README.md
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-12-2020_2200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-28-2020_1800.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-13-2020_1000.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-07-2020_2024.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-24-2020_1200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-26-2020_2300.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-04-2020_2200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-29-2020_2100.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-25-2020_1200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-29-2020_1430.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-02-2020_2100.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-05-2020_1220.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-02-2020_1945.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-09-2020_2320.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-09-2020_1030.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-01-2020_1800.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-04-2020_0800.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-28-2020_1300.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-10-2020_1030.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-29-2020_1330.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-30-2020_2130.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-25-2020_2200.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-13-2020_2115.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/01-25-2020_0000.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-11-2020_1050.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-01-2020_2300.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-01-2020_1000.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-04-2020_1150.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-14-2020_1123.csv
# /kaggle/input/covid19/archived_data/archived_daily_case_updates/02-10-2020_1930.csv
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_2019-ncov-Confirmed.csv
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_19-covid-Deaths_archived_0325.csv
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_2019-ncov-Recovered.csv
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_2019-ncov-Deaths.csv
# /kaggle/input/covid19/archived_data/archived_time_series/.gitignore
# /kaggle/input/covid19/archived_data/archived_time_series/README.md
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_19-covid-Confirmed_archived_0325.csv
# /kaggle/input/covid19/archived_data/archived_time_series/time_series_19-covid-Recovered_archived_0325.csv

# %%
file_name = ("/kaggle/input/covid19/csse_covid_19_data/csse_covid_19_daily_reports_us/04-12-2020.csv")
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#   Province_State Country_Region          Last_Update      Lat     Long_  \
# 0        Alabama             US  2020-04-12 23:18:15  32.3182  -86.9023
# 1         Alaska             US  2020-04-12 23:18:15  61.3707 -152.4044
# 2        Arizona             US  2020-04-12 23:18:15  33.7298 -111.4312
# 3       Arkansas             US  2020-04-12 23:18:15  34.9697  -92.3731
# 4     California             US  2020-04-12 23:18:15  36.1162 -119.6816
#
#    Confirmed  Deaths  Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0       3563      93        NaN    3470   1.0      75.988020        21583.0
# 1        272       8       66.0     264   2.0      45.504049         8038.0
# 2       3542     115        NaN    3427   4.0      48.662422        42109.0
# 3       1280      27      367.0    1253   5.0      49.439423        19722.0
# 4      22795     641        NaN   22154   6.0      58.137726       190328.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 0                437.0        2.610160  84000001  USA    460.300152
# 1                 31.0        2.941176  84000002  USA   1344.711576
# 2                  NaN        3.246753  84000004  USA    578.522286
# 3                130.0        2.109375  84000005  USA    761.753354
# 4               5234.0        2.812020  84000006  USA    485.423868
#
#    Hospitalization_Rate
# 0             12.264945
# 1             11.397059
# 2                   NaN
# 3             10.156250
# 4             22.961176

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Simple Linear Regression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X = df[["Active"]]
Y = df[["Confirmed"]]

# %%
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yhat = lm.predict(X)
yhat[0:10]
# Out:
# array([[ 4344.76470551],
#        [ 1101.91989491],
#        [ 4301.27052995],
#        [ 2102.28593286],
#        [23243.48973399],
#        [ 7933.53993571],
#        [12447.8307622 ],
#        [ 2443.15889018],
#        [  884.44901709],
#        [ 2680.8596171 ]])

# %%
lm.intercept_
# Out:
# array([834.8858868])

# %%
lm.coef_
# Out:
# array([[1.01149245]])

# %% [markdown]
# # Equation of predicted line
#
#         Confirmed = 834.8858868 + 1.01149245 * Active

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
width = 15
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="Active", y="Confirmed", data=df)

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['Active'], df['Confirmed'])
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %%
Z = df[["Active", "Confirmed"]]
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (59, 2)

# %%
Z_pr.shape
# Out:
# (59, 6)

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
pipe.fit(Z, Y)
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([[3563.],
#        [ 272.],
#        [3542.],
#        [1280.]])

# %%
lm.fit(X, Y)
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.9709046123701057

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [[4344.76470551]
#  [1101.91989491]
#  [4301.27052995]
#  [2102.28593286]]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['Confirmed'], Yhat)
print('The mean square error of Confirmed cases and predicted value is: ', mse)
# Out:
# The mean square error of Confirmed cases and predicted value is:  19184480.15637814

# %%
lm.fit(Z, df['Confirmed'])
print('The R-square is: ', lm.score(Z, df['Confirmed']))
# Out:
# The R-square is:  1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# array([[835.89737925],
#        [836.90887171],
#        [837.92036416],
#        [838.93185662],
#        [839.94334907]])

# %%
plt.plot(new_input, yhat)
plt.show()
